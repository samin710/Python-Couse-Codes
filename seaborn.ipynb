# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Total bill vs tip")
plt.show()

# %% [markdown]
# # Line plot

# %%
sns.lineplot(x="size", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# # Categorical plots

# %%
# Bar plot

sns.barplot(x="day", y="total_bill", data=tips, color="lightgreen")
plt.show()

# %% [markdown]
# # Box plot

# %%
sns.boxenplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# # Histograms

# %%
sns.histplot(tips["total_bill"], bins=10, kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# # KDE plots

# %%
sns.kdeplot(tips["total_bill"], fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Pair plot
# pair plot diye data set ar sob features(numerical) ar sob features(numrical) moddhe relationship dekhano hoy

# %%
sns.pairplot(tips)

# %% [markdown]
# # Heat map

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
corr = tips[["total_bill", "tip", "size"]].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
import pandas as pd

df  = pd.read_csv("sample_data.csv")
df.head(5)
# Out:
#          Date     Category   Value   Product  Sales Region
# 0  2024-05-24    Furniture  715.60      Milk    NaN   West
# 1  2024-08-30         Toys  822.15      Sofa   54.0  North
# 2  2024-10-17  Electronics  601.09      Doll   99.0   West
# 3  2024-01-06         Toys  382.01     Shirt   69.0  South
# 4  2024-05-30    Furniture  327.38  Football    9.0   East

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Category", y="Sales", data=df, estimator=sum)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>
